# %% [markdown]
# ## Importing Libraries

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait as WDW
from selenium.webdriver.support import expected_conditions as EC
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# ## Set up and configure Selenium Web_Driver

# %%
print("Setting up Webdriver....")
chrome_opt = Options() # Initialize the chrome webdriver
chrome_opt.add_argument("--headless")
chrome_opt.add_argument("--disable-gpu")
chrome_opt.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/131.0.6778.265 Safari/537.36")
print("configuration done!")
# Out:
# Setting up Webdriver....
# configuration done!

# %%
# Setting up webdriver: Installation
print("Installing Chrome webdriver")
service = Service(ChromeDriverManager ().install())
print("Final setup")
driver = webdriver.Chrome(service=service, options=chrome_opt)
# Out:
# Installing Chrome webdriver
# Final setup

# %% [markdown]
# ## Making a connection to the Web page

# %%
URL= "https://www.glassesusa.com/eyeglasses-collection"

# %%
print(f"Visiting {URL} page")
driver.get(URL)

# Further Instructions
try:
    print("Waiting for product tiles to load")
    WDW(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, 'uw-sl')))
    print("Done, Proceed!")
except TimeoutError as e:
    print(f"Expected tag did not load on time: {e}")
    pass
# Out:
# Visiting https://www.glassesusa.com/eyeglasses-collection page
# Waiting for product tiles to load
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[11], line 7
#       5 try:
#       6     print("Waiting for product tiles to load")
# ----> 7     WDW(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, 'uw-sl')))
#       8     print("Done, Proceed!")
#       9 except TimeoutError as e:
#
# File c:\Users\ADMIN\Documents\GitHub\Web Scraping Eye care project\venv\Lib\site-packages\selenium\webdriver\support\wait.py:138, in WebDriverWait.until(self, method, message)
#     136         break
#     137     time.sleep(self._poll)
# --> 138 raise TimeoutException(message, screen, stacktrace)
#
# TimeoutException: Message:
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x97cdf3+10b03]
# 	chromedriver!GetHandleVerifier [0x97cf24+10c34]
# 	chromedriver!(No symbol) [0x762120]
# 	chromedriver!(No symbol) [0x7aabca]
# 	chromedriver!(No symbol) [0x7aae6b]
# 	chromedriver!(No symbol) [0x7ed0b2]
# 	chromedriver!(No symbol) [0x7cdb54]
# 	chromedriver!(No symbol) [0x7ea9a5]
# 	chromedriver!(No symbol) [0x7cd8a6]
# 	chromedriver!(No symbol) [0x7a0229]
# 	chromedriver!(No symbol) [0x7a0fe4]
# 	chromedriver!GetHandleVerifier [0xbe48b9+2785c9]
# 	chromedriver!GetHandleVerifier [0xbdfeb5+273bc5]
# 	chromedriver!GetHandleVerifier [0xbfe06b+291d7b]
# 	chromedriver!GetHandleVerifier [0x995cc8+299d8]
# 	chromedriver!GetHandleVerifier [0x99d9fd+3170d]
# 	chromedriver!GetHandleVerifier [0x9858c8+195d8]
# 	chromedriver!GetHandleVerifier [0x985a92+197a2]
# 	chromedriver!GetHandleVerifier [0x96ee9a+2baa]
# 	KERNEL32!BaseThreadInitThunk [0x767d5d49+19]
# 	ntdll!RtlInitializeExceptionChain [0x776bd81b+6b]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x776bd7a1+231]

# %%
content = driver.page_source
page = BeautifulSoup(content, "html.parser")

# %% [markdown]
# ## Data Extraction

# %%
GUwtT_Vlamf = page.find_all('div', class_="GUwtT_Vlamf")
# Filter to only actual products (exclude ads)
prod_holder = [p for p in prod_holder if p.get('data-element-id', '').startswith('Tiles_Tile')]
print(f"Found {len(prod_holder)} products on the page.")
